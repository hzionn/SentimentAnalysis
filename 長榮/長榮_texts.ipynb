# %%
import pandas as pd
import numpy as np

# %%
texts = ''
zhongguo = pd.read_csv('長榮_中國報_cleaned.csv')
zhongguo = zhongguo.dropna()

for comment in zhongguo['COMMENTS']:
    texts += comment

dongsen = pd.read_csv('長榮_東森新聞_cleaned.csv')
dongsen = dongsen.dropna()

for comment in dongsen['COMMENTS']:
    texts += comment

ettoday = pd.read_csv('長榮_ETtoday新聞網_cleaned.csv')
ettoday = ettoday.dropna()

for comment in ettoday['COMMENTS']:
    texts += comment

lianhe = pd.read_csv('長榮_聯合報_cleaned.csv')
lianhe = lianhe.dropna()

for comment in lianhe['COMMENTS']:
    texts += comment

print(len(texts))
print(texts)
# Out:
# 31488
# ...
