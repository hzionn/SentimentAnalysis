# %% [markdown]
# # [fb中國報](https://www.facebook.com/ChinaPressCP/posts/3570730819686004)

# %%
import pandas as pd
import re, time, requests
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup as bs
from pprint import pprint
import os

# %%
def reply_comment():
    #留言中的留言
    ele = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/div[2]/div[2]/div[2]/div[2]/div/div/div/div/div/div/div/div[1]/div/div[2]/div[2]/form/div/div[3]/ul/li[1]/div[2]/div/a/div/span')
    driver.execute_script("arguments[0].click();", ele)
    time.sleep(2)

def expand_comments():
    #滑到最下面
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    #點「查看更多留言」
    ele = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/div[2]/div[2]/div[2]/div[2]/div/div/div/div/div/div/div/div[1]/div/div[2]/div[2]/form/div/div[3]/div[2]/div/a/div/span')
    driver.execute_script("arguments[0].click();", ele)
    time.sleep(2)
    try:
        for i in range(5):
            ele = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/div[2]/div[2]/div[2]/div[2]/div/div/div/div/div/div/div/div[1]/div/div[2]/div[2]/form/div/div[3]/ul/li[1]/div[2]/div/a/div/span')
            driver.execute_script("arguments[0].click();", ele)
            time.sleep(2)
    except:
        None

# %%
url = 'https://www.facebook.com/ChinaPressCP/posts/3570730819686004'

driver = webdriver.Chrome(executable_path=r"/Users/zionn/.wdm/drivers/chromedriver/mac64/87.0.4280.88/chromedriver")
driver.get(url)
time.sleep(5)

#關登陸頁面
driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/div[2]/div[2]/div[1]/div/div[2]/div[2]/div[4]/a').click()
time.sleep(2)

#打開留言
element = driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[1]/div/div[2]/div[2]/div[2]/div[2]/div/div/div/div/div/div/div/div[1]/div/div[2]/div[2]/form/div/div[2]/div[1]/div/div[3]/span[1]/a")
driver.execute_script("arguments[0].click();", element)
time.sleep(2)

#選留言選項
element = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/div[2]/div[2]/div[2]/div[2]/div/div/div/div/div/div/div/div[1]/div/div[2]/div[2]/form/div/div[3]/div[1]/div/div/div/div/a')
driver.execute_script("arguments[0].click();", element)
time.sleep(2)

#選「全部留言」
element = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[3]/div/div/div/ul/li[3]/a')
driver.execute_script("arguments[0].click();", element)
time.sleep(2)



for i in range(20):
    try:
        expand_comments()
    except:
        None

htmltext = driver.page_source
soup = BeautifulSoup(htmltext, 'lxml')

for item in soup.find_all('span', attrs={'class':'_3l3x'}):
    item.find('span').text

print(len(soup.find_all('span', attrs={'class':'_3l3x'})))

#driver.close()
# Out:
# 191

# %%
htmltext = driver.page_source
soup = BeautifulSoup(htmltext, 'lxml')

html_tag = soup.find_all('span', attrs={'class':'_3l3x'})
print(len(html_tag))

comments = []
for item in html_tag:
    try:
        comment = item.find('span').text
        #print(comment)
        comments.append(comment)
    except:
        None

comments
# Out:
# 456
# ['对不起，这位妈妈，恐怕要你失望了。在那个国家公道只会在人心而已。司法是不可能给你一个合理的公道的。恐龙法官宁可惹众怒，也不可能下判死刑的。只会告诉你，政府是不会执行的。死脑筋，人权？在被告剥夺别人的生命权，侵犯别人的人权时，他就丧失了本身的人权。凭什么他们可以扼杀死者的人权，而你们去维护罪犯的人权了。',
#  '台湾法律一定要变，一定要严厉对付这种杀人犯！',
#  '台湾法律一定要，严厉对付这种杀人犯！！😤😤😤',
#  'Carmen Ng 是不对的行為',
#  'Carmen Ng 那里可以这样，大家都不怕可以繼續干壞事',
#  '長榮大學，全馬人都得記得校方的無能，  希望想到外留學的學生慎重考慮，臺灣已經不是十年前的臺灣，現在的臺灣很危險。校方的忽視，檢察官的懈怠，法官的不作為，人民的無差別殺人。這一切都得記清楚了！笑著去留學，回來可能就裝罐子裡了！我不是散播恐怖，但是今年已經是第二宗馬來西亞女子在臺灣被獵殺！希望我國能看重國人的安全，做出有程度的譴責！',
#  'Kelly Xu 他也沒敢回我，他們這種人就是愛亂扣帽子，我言論裡面並沒有涉及兩岸問題，他們就愛把個別案件上昇到兩岸問題。',
#  'Tan Kok 通过你的言谈，很明显看得出你是这种无理搅三分的闲杂人，在网络被炮轰了还在给自己解脱耍赖，实在是给你的国家丢脸！先前看你讲话还有几分礼貌我才礼貌的回答你，如今看到你这样的答复，让我感觉到一副狗急跳墙的模样……你还是洗洗睡吧……',
#  'Tan Kok  你敢来马来西亚，我想你也会被炸飞！来吧～welcome to Malaysia~',
#  'Kelly Xu 那么Mongolian 女郎在马来西亞被殺也可以叫马国人“马狗还命来“！快啊～',
#  'Tan Kok  杀人必须偿命！管你什么程序？不然要法律摆美的？一单接着一单，一个国家连法律都漏洞百出，怎么给世界一个交代？法律定刑实行判决根据犯罪事实的轻重，倘若情节严重，证据确凿，应该定量而行！给社会一个公平的交代，也给那些受害人家属一个交代……不对吗？',
# ...

# %%
dic = {"COMMENTS":comments}
df = pd.DataFrame(dic)
print(df)
df.to_csv(os.getcwd()+'/長榮_中國報.csv')
# Out:
#                                               COMMENTS
# 0    对不起，这位妈妈，恐怕要你失望了。在那个国家公道只会在人心而已。司法是不可能给你一个合理的公...
# 1                               台湾法律一定要变，一定要严厉对付这种杀人犯！
# 2                               台湾法律一定要，严厉对付这种杀人犯！！😤😤😤
# 3                                     Carmen Ng 是不对的行為
# 4                        Carmen Ng 那里可以这样，大家都不怕可以繼續干壞事
# ..                                                 ...
# 448                                            可教化，可教化
# 449                Shen Joo 当然，那些废物联盟的亲人没被人害死过，所以不觉得痛。
# 450                  Richard Chan 是有死刑，只不過会被那些废死联盟百般阻挠
# 451                                        绝对是预谋杀害必须严惩
# 452                                       那你就在监狱被勒死的滋味
#
# [453 rows x 1 columns]

# %% [markdown]
# # [東森新聞](https://www.facebook.com/news.ebc/videos/3921911587836876)

# %%
url = 'https://www.facebook.com/news.ebc/videos/3921911587836876'

driver = webdriver.Chrome(executable_path=r"/Users/zionn/.wdm/drivers/chromedriver/mac64/87.0.4280.88/chromedriver")
driver.get(url)
time.sleep(5)

#關登陸頁面
try:
    driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/div[2]/div[2]/div[1]/div/div[2]/div[2]/div[4]/a').click()
    time.sleep(2)
except:
    None
time.sleep(2)

#打開留言
element = driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[1]/div/div[3]/div/div[1]/div[2]/div/div/div/div[2]/div/div[1]/div/div[2]/div[2]/form/div/div[2]/div[1]/div/div[3]/span[1]/a")
driver.execute_script("arguments[0].click();", element)
time.sleep(2)

#選留言選項
element = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/div[3]/div/div[1]/div[2]/div/div/div/div[2]/div/div[1]/div/div[2]/div[2]/form/div/div[3]/div[1]/div/div/div/div/a')
driver.execute_script("arguments[0].click();", element)
time.sleep(2)

#選「全部留言」
element = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[3]/div/div/div/ul/li[3]/a')
driver.execute_script("arguments[0].click();", element)
time.sleep(2)

for i in range(20):
    try:
        element = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/div[3]/div/div[1]/div[2]/div/div/div/div[2]/div/div[1]/div/div[2]/div[2]/form/div/div[3]/div[2]/div/a/div/span')
        driver.execute_script("arguments[0].click();", element)
    except:
        None

htmltext = driver.page_source
soup = BeautifulSoup(htmltext, 'lxml')

for item in soup.find_all('span', attrs={'class':'_3l3x'}):
    item.find('span').text

print(len(soup.find_all('span', attrs={'class':'_3l3x'})))

#driver.close()
# Out:
# 2

# %%
htmltext = driver.page_source
soup = BeautifulSoup(htmltext, 'lxml')

html_tag = soup.find_all('span', attrs={'class':'_3l3x'})
print(len(html_tag))

comments = []
for item in html_tag:
    try:
        comment = item.find('span').text
        #print(comment)
        comments.append(comment)
    except:
        None

comments
# Out:
# 307
# ['台灣治安愈來愈亂，該如何自保呢！每天都看到殺人的事，真是悲哀。但願人人都有自保，防身的能力。不要再有人受害了，很難過！😭',
#  'Johnny Jiang 這麼愛統一,那就過來試試看...😡',
#  'Adom Hsu 也许自备一把枪或者刀',
#  'Adom Hsu 统一可以彻底改造拯救台湾省',
#  '不會判死的啦，肯定是可教化。死的是別人的女兒，除非死的是法官的女兒，才會判死',
#  'Ivan IL I’m so sad. Under jurisdiction of Taiwan, there have no punishment in death... I hope the girl can rest in peace, RIP.. ',
#  'Taiwan 原来是个不会处死坏人的国家。现在坏人肯定认为自己都有法官保护的，怕什么犯案和杀人',
#  'Ivan ILTaiwan 是没有绞刑。under the jurisdiction of Taiwan , the murderers will not get the punishment in death sentence. Sad right ... 😞',
#  '太扯了以後誰敢在路上走',
#  'Johnny Jiang 有病要盡快就醫',
#  'Johnny Jiang 又關你何事?',
#  '盧晶晶 玻璃粉紅的病是絕症,醫不了的...😆',
#  '盧晶晶 可是不统一 会越来越多随意奸 随便杀 分块装袋到处扔案件发生哦！',
#  '盧晶晶 统一可以彻底改造拯救台湾省',
#  'Rui Zhe 可是看回地图，还真是必经之路……',
#  '主要是燈光昏暗小道，盡量走人多光亮地方，繞路也沒關係，安全第一',
#  '可以請大法官釋憲～亂世祭重典',
#  '吳允中 想想也是',
#  '黄峻林 這種小事大法官不屑處理的，下一個！',
#  'Taiwan Police is a laughingstock n total disgraceful!',
#  '沒想到？？？電車上無差別殺人都發生過了。',
#  '連大白天走在路上都會了，還這種晚上沒路燈的',
#  '一樣不可置信阿',
#  '這次在在無罪，我建議我們去法院丟汽油',
# ...

# %%
dic = {"COMMENTS":comments}
df = pd.DataFrame(dic)
print(df)
df.to_csv(os.getcwd()+'/長榮_東森新聞.csv')
# Out:
#                                               COMMENTS
# 0    台灣治安愈來愈亂，該如何自保呢！每天都看到殺人的事，真是悲哀。但願人人都有自保，防身的能力。...
# 1                       Johnny Jiang 這麼愛統一,那就過來試試看...😡
# 2                                  Adom Hsu 也许自备一把枪或者刀
# 3                               Adom Hsu 统一可以彻底改造拯救台湾省
# 4               不會判死的啦，肯定是可教化。死的是別人的女兒，除非死的是法官的女兒，才會判死
# ..                                                 ...
# 301                                               支持死刑
# 302                                         怎麼有那麼變態的人啦
# 303                                         鬼島，全靠可教化法官
# 304                                               求判死刑
# 305                                            唉呀，怎麼搞的
#
# [306 rows x 1 columns]

# %% [markdown]
# # [聯合報](https://www.facebook.com/udnplus/posts/1906028499549915)

# %%
url = 'https://www.facebook.com/udnplus/posts/1906028499549915'

driver = webdriver.Chrome(executable_path=r"/Users/zionn/.wdm/drivers/chromedriver/mac64/87.0.4280.88/chromedriver")
driver.get(url)
time.sleep(5)

#關登陸頁面
driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/div[2]/div[2]/div[1]/div/div[2]/div[2]/div[4]/a').click()
time.sleep(2)

#打開留言
element = driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[1]/div/div[2]/div[2]/div[2]/div[2]/div/div/div/div/div/div/div/div[1]/div/div[2]/div[2]/form/div/div[2]/div[1]/div/div[3]/span[1]/a")
driver.execute_script("arguments[0].click();", element)
time.sleep(2)

#選留言選項
element = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/div[2]/div[2]/div[2]/div[2]/div/div/div/div/div/div/div/div[1]/div/div[2]/div[2]/form/div/div[3]/div[1]/div/div/div/div/a')
driver.execute_script("arguments[0].click();", element)
time.sleep(2)

#選「全部留言」
element = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[3]/div/div/div/ul/li[3]/a')
driver.execute_script("arguments[0].click();", element)
time.sleep(2)

for i in range(20):
    try:
        expand_comments()
    except:
        None

htmltext = driver.page_source
soup = BeautifulSoup(htmltext, 'lxml')

for item in soup.find_all('span', attrs={'class':'_3l3x'}):
    item.find('span')

print(len(soup.find_all('span', attrs={'class':'_3l3x'})))

#driver.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-c0ee81bf857b> in <module>
#      34
#      35 for item in soup.find_all('span', attrs={'class':'_3l3x'}):
# ---> 36     item.find('span').text
#      37
#      38 print(len(soup.find_all('span', attrs={'class':'_3l3x'})))
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
htmltext = driver.page_source
soup = BeautifulSoup(htmltext, 'lxml')

html_tag = soup.find_all('span', attrs={'class':'_3l3x'})
print(len(html_tag))

comments = []
for item in html_tag:
    try:
        comment = item.find('span').text
        #print(comment)
        comments.append(comment)
    except:
        None

comments
# Out:
# 319
# ['擄殺女大生嫌犯承認預謀性侵 竟回「不知道會勒死人」',
#  ' 都敢殺人了。到底為什麼要遮臉',
#  '文榮 我看有大陸網友說他有顏值怎麼會是變態犯🤣',
#  'Ming Hui Tsai 反正殺警殺母砍下母頭都無罪釋放',
#  '文榮 因為人都死了⋯⋯只能保護還有生命的人啊！這就是那些法官上層的教育體系，流傳下來的啊？！🤔',
#  '彭詠沛 這點自然是沒臉見人，帶上安全帽是司法制度防止被家屬追打或自尋短處。',
#  '郭大家 原來如此',
#  '梁育誌一開始滿口謊言 警：他企圖脫罪https://bit.ly/35NilrT凶嫌承認勒脖否認想殺人',
#  '它不用“企圖”脫罪，法官會主動用盡一切努力幫它脫罪的……',
#  '大馬女大學生不知台灣是殺人案頻傳來台灣唸書',
#  '这就是台湾的司法，杀人就不用偿命，这是什么司法，要给往生女大学生父母一个交代，给马来西亚人民交代，一命还一命😡😡😡',
#  ' 他當然會這麼說看會不會免死',
#  '臺灣是犯罪者的天堂！',
#  'Chen An Kuei  也是守法人的地獄。',
#  'Chen An Kuei',
#  '看看台灣人命跟大馬女大學生命誰值錢',
#  '台灣是天堂？地獄？',
#  'Chen An Kuei',
#  '怎沒有人衝出去簒他幾腳阿。',
#  '陳志暉 我也怎麼想',
#  '陳志暉 應該打爆他的頭踹爛他的下體',
#  '陳志暉 如果在現場 有可能忍不住',
#  '陳志暉 踹不了D，保護的很好呢，',
#  '陳志暉 我真的很想打他幾個巴掌，太可惡了',
#  '政府可否多花心思,在國人的品格教育及道德價值觀?!而非政治和名利及權力鬥爭😡😡😡看看政客墮落和平民品格扭曲,不會感到憂慮嗎?還會',
#  '李羚 如果有羞恥感，怎麼會去當政客，怎麼會開政治空頭支票，怎麼會去製造分化對立？',
#  '李羚 我的小孩子國小教育禮義廉恥都不教了，你說呢？',
#  '我不敢指望現在的執政黨能有什麼做為，',
#  'Will Liao 無奈之餘🙄自己只能默默付出,做對的事,該做的事,但往往感到緩不濟急,滿心的無力感😵',
#  'Chih Hsin Hung 現在父母真的難為,上一代父母,生活雖困苦,但有國家義務教育教導,父母只需配合。',
# ...

# %%
dic = {"COMMENTS":comments}
df = pd.DataFrame(dic)
print(df)
df.to_csv(os.getcwd()+'/長榮_聯合報.csv')
# Out:
#                                             COMMENTS
# 0                          擄殺女大生嫌犯承認預謀性侵 竟回「不知道會勒死人」
# 1                                     都敢殺人了。到底為什麼要遮臉
# 2                            文榮 我看有大陸網友說他有顏值怎麼會是變態犯🤣
# 3                      Ming Hui Tsai 反正殺警殺母砍下母頭都無罪釋放
# 4    文榮 因為人都死了⋯⋯只能保護還有生命的人啊！這就是那些法官上層的教育體系，流傳下來的啊？！🤔
# ..                                               ...
# 311                           王八蛋 😡 打給牠死 💀 👊 🤬 雜碎 垃圾
# 312                                 廢死聯盟，怎麼不出來吠兩聲啦!幹
# 313                                           剪刀在哪兒？
# 314                                               死刑
# 315                          廢死聯盟！！又有文章可以做了，又可以出來亂了！
#
# [316 rows x 1 columns]

# %% [markdown]
# # [ETtoday新聞網](https://www.facebook.com/ETtoday/posts/3927522627283872)

# %%
url = 'https://www.facebook.com/ETtoday/posts/3927522627283872'

driver = webdriver.Chrome(executable_path=r"/Users/zionn/.wdm/drivers/chromedriver/mac64/87.0.4280.88/chromedriver")
driver.get(url)
time.sleep(5)

#關登陸頁面
driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/div[2]/div[2]/div[1]/div/div[2]/div[2]/div[4]/a').click()
time.sleep(2)

#打開留言
element = driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[1]/div/div[2]/div[2]/div[2]/div[2]/div/div/div/div/div/div/div/div[1]/div/div[2]/div[2]/form/div/div[2]/div[1]/div/div[3]/span[1]/a")
driver.execute_script("arguments[0].click();", element)
time.sleep(2)

#選留言選項
element = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[1]/div/div[2]/div[2]/div[2]/div[2]/div/div/div/div/div/div/div/div[1]/div/div[2]/div[2]/form/div/div[3]/div[1]/div/div/div/div/a')
driver.execute_script("arguments[0].click();", element)
time.sleep(2)

#選「全部留言」
element = driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[3]/div/div/div/ul/li[3]/a')
driver.execute_script("arguments[0].click();", element)
time.sleep(2)



for i in range(20):
    try:
        expand_comments()
    except:
        None

htmltext = driver.page_source
soup = BeautifulSoup(htmltext, 'lxml')

for item in soup.find_all('span', attrs={'class':'_3l3x'}):
    item.find('span').text

print(len(soup.find_all('span', attrs={'class':'_3l3x'})))

#driver.close()
# Out:
# 150

# %%
htmltext = driver.page_source
soup = BeautifulSoup(htmltext, 'lxml')

html_tag = soup.find_all('span', attrs={'class':'_3l3x'})
print(len(html_tag))

comments = []
for item in html_tag:
    try:
        comment = item.find('span').text
        #print(comment)
        comments.append(comment)
    except:
        None

comments
# Out:
# 209
# ['身為一個媽媽該有多痛，真的好讓人揪心',
#  'Miya Hsu 不是媽媽也該有同理心，這麼冷血不配當人是畜牲😡😡',
#  'Ann Chien 雖然我沒經歷此事，但聽到這哭聲讓我由如心被用力的扭，真難過',
#  '鄭尹慈 真的很痛超痛',
#  '鄭尹慈 他不是媽媽～～看不見心中淌血的媽媽😭😭😭',
#  '小英總統聽到媽媽的吶喊聲了沒有？',
#  'Li Ta 我了解你的憤怒💢我也支持死刑👍',
#  'Nick Wang 小燈泡事件真的會讓人想打人。',
#  'Nick Wang 啊，我也不是針對你，不好意思。看到屢屢發生這種死者和殺人犯的人權極不平等的案件真的火都上來。',
#  '龙霸天 痾...這裡是臺灣，我只是講臺灣現在的情況==',
#  'Nick Wang 死刑有什麼難的？你看新加坡有很難做到嗎？誰敢要求廢死直接送去新加坡教育！',
#  'Helen Chen 没4过所以不懂也有可能她不懂(4)这个字(4)的14',
#  '林玠賢 失败国是这样的做风。每一个国家都要有4行才会强',
#  'Chiu Chi Huang 又不是她儿子女儿亲人她那会心痛如果表面上会也是假假做戏给人民看',
#  'Chiu Chi Huang 跟聾子講話 她能聽到嗎',
#  'Chiu Chi Huang 已經讓全世界知道台灣了',
#  'Chiu Chi Huang 總統聽不到 有聽到 早就判死刑了！',
#  'Chiu Chi Huang 沒當過媽媽無法理解',
#  'Jessica Ting 蔡英文本來就沒當媽了,為什麼沒當媽就543??你這是歧視喔',
#  '林玠賢 因為這層 只有那位在幫犯人講人權⋯',
#  'Li Ta 我沒有特定的說人權的，不過這次事情對於所有人來說是真的很難過的，最希望的是政府除了還死者家屬一個公道外，也希望以後政府也能監督台灣的法官，不再有什麼有教化可能來輕判（當然是希望以後別再有兇殺案是最好的）',
#  '陳信良 就大選時咩  然後再開恩釋放一些快出獄的受刑人',
#  '郭柏劭 一旦做出不是人該做的事  就沒有資格講究人權！要求人權！',
#  '林玠賢 講人權的是這位⋯你好像回錯人了',
# ...

# %%
dic = {"COMMENTS":comments}
df = pd.DataFrame(dic)
print(df)
df.to_csv(os.getcwd()+'/長榮_ETtoday新聞網.csv')
# Out:
#                                     COMMENTS
# 0                         身為一個媽媽該有多痛，真的好讓人揪心
# 1          Miya Hsu 不是媽媽也該有同理心，這麼冷血不配當人是畜牲😡😡
# 2    Ann Chien 雖然我沒經歷此事，但聽到這哭聲讓我由如心被用力的扭，真難過
# 3                                 鄭尹慈 真的很痛超痛
# 4                   鄭尹慈 他不是媽媽～～看不見心中淌血的媽媽😭😭😭
# ..                                       ...
# 204                                    🥺我都哭了
# 205                                    要隔離嗎？
# 206           最該下台的綠淫小陰，小陰拿到總統位置後，台灣人的命就不值錢，
# 207                有頭有臉才能有這樣待遇 如今天是平民百姓應該就……
# 208                              好難過啊！怎麼撐下去呢
#
# [209 rows x 1 columns]
